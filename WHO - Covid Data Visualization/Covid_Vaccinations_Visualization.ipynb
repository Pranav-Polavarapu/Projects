# %% [markdown]
# <a href="https://colab.research.google.com/github/KEERTHICHELLURI/Projects/blob/main/Covid_Vaccinations_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install raceplotly
from raceplotly.plots import barplot
# Out:
# Collecting raceplotly
#   Downloading raceplotly-0.1.6-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from raceplotly) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from raceplotly) (1.1.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from raceplotly) (4.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->raceplotly) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->raceplotly) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->raceplotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->raceplotly) (1.3.3)
# Installing collected packages: raceplotly
# Successfully installed raceplotly-0.1.6

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ee61433-0f39-4fdc-899e-1d0ec7f0dbab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ee61433-0f39-4fdc-899e-1d0ec7f0dbab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vaccinations.csv to vaccinations.csv

# %%
import io
import pandas as pd
import numpy as np
  
df = pd.read_csv(io.BytesIO(uploaded['vaccinations.csv']))
print(df)
# Out:
#           location  ... daily_people_vaccinated_per_hundred
# 0      Afghanistan  ...                                 NaN
# 1      Afghanistan  ...                               0.003
# 2      Afghanistan  ...                               0.003
# 3      Afghanistan  ...                               0.003
# 4      Afghanistan  ...                               0.003
# ...            ...  ...                                 ...
# 64324     Zimbabwe  ...                               0.187
# 64325     Zimbabwe  ...                               0.172
# 64326     Zimbabwe  ...                               0.161
# 64327     Zimbabwe  ...                               0.147
# 64328     Zimbabwe  ...                               0.125
#
# [64329 rows x 16 columns]

# %%
my_raceplot = barplot(df,  item_column='location', value_column='daily_vaccinations', time_column='date')
my_raceplot.plot(title='Daily Vaccinations', item_label = 'Country', value_label = 'Daily Vaccination number',
                time_label = 'Date: ', frame_duration = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c51284fb-5c9f-4a64-b456-e9726f5c5baf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c51284fb-5c9f-4a64-b456-e9726f5c5baf")) {
#                     Plotly.newPlot(
#                         'c51284fb-5c9f-4a64-b456-e9726f5c5baf',
#                         [{"cliponaxis": false, "hoverinfo": "all", "marker": {"color": ["rgb(183, 125, 22)", "rgb(58, 215, 239)", "rgb(182, 190, 201)", "rgb(30, 4, 1)", "rgb(117, 67, 66)"]}, "orientation": "h", "textangle": 0, "textposition": "outside", "texttemplate": "%{y}<br>%{x:.4s}", "type": "bar", "x": [null, null, null, null, null], "y": ["Denmark", "Europe", "European Union", "High income", "World"]}],
#                         {"bargap": 0.15, "font": {"size": 14}, "plot_bgcolor": "#FFFFFF", "sliders": [{"active": 0, "currentvalue": {"font": {"size": 20}, "prefix": "Date: ", "visible": true, "xanchor": "right"}, "len": 0.9, "pad": {"b": 10, "t": 50}, "steps": [{"args": [["2020-12-01"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-01", "method": "animate"}, {"args": [["2020-12-02"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-02", "method": "animate"}, {"args": [["2020-12-03"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-03", "method": "animate"}, {"args": [["2020-12-04"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-04", "method": "animate"}, {"args": [["2020-12-05"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-05", "method": "animate"}, {"args": [["2020-12-06"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-06", "method": "animate"}, {"args": [["2020-12-07"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-07", "method": "animate"}, {"args": [["2020-12-08"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-08", "method": "animate"}, {"args": [["2020-12-09"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-09", "method": "animate"}, {"args": [["2020-12-10"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-10", "method": "animate"}, {"args": [["2020-12-11"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-11", "method": "animate"}, {"args": [["2020-12-12"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-12", "method": "animate"}, {"args": [["2020-12-13"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-13", "method": "animate"}, {"args": [["2020-12-14"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-14", "method": "animate"}, {"args": [["2020-12-15"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-15", "method": "animate"}, {"args": [["2020-12-16"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-16", "method": "animate"}, {"args": [["2020-12-17"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-17", "method": "animate"}, {"args": [["2020-12-18"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-18", "method": "animate"}, {"args": [["2020-12-19"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-19", "method": "animate"}, {"args": [["2020-12-20"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-20", "method": "animate"}, {"args": [["2020-12-21"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition": {"duration": 600}}], "label": "2020-12-21", "method": "animate"}, {"args": [["2020-12-22"], {"frame": {"duration": 600, "redraw": false}, "mode": "immediate", "transition" ...
